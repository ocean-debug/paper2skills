# %% [markdown]
# # Omics notebook tutorial

# %%
input_dir = 'data'
output_path = 'results/notebook_scores.tsv'

# %%
# !pip install omicsnotebook
# !wget https://example.invalid/reference.tsv

# %%
# %%capture
matrix_path = input_dir + '/matrix.csv'
matrix = read_csv(matrix_path)
write(output_path, matrix)

# %%
# %%R
# library(OmicsR)
# obj <- readRDS('data/object.rds')

# %%
# %%bash
# echo done > results/done.txt
